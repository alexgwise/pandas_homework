# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csv_path = Path('whale_returns.csv')
df_whale = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
df_whale.sort_index(inplace=True)
df_whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
df_whale.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
df_whale = df_whale.dropna()

# %%
# Confirm nulls were dropped
df_whale.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csv_path = Path('algo_returns.csv')
df_algo = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
df_algo.sort_index(inplace=True)
df_algo.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
df_algo.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
df_algo = df_algo.dropna()

# %%
# Confirm nulls were dropped, view first five rows
df_algo.isnull().sum()
df_algo.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csv_path = Path('sp500_history.csv')
df_sp500 = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
df_sp500.sort_index(inplace=True)
df_sp500.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
df_sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Get rid of $ symbols so we can convert the object/string to a float
df_sp500["Close"] = df_sp500["Close"].str.replace("$", "")
df_sp500.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Fix Data Types
df_sp500["Close"] = df_sp500["Close"].astype("float")

# %%
# Confirm Data Type change
df_sp500.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
df_sp500_daily_returns = df_sp500.pct_change()
df_sp500_daily_returns
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
df_sp500_daily_returns = df_sp500_daily_returns.dropna()
df_sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
df_sp500_daily_returns = df_sp500_daily_returns.rename(columns={
    "Close": "S&P 500"})
df_sp500_daily_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
# note for self. will use axis = columns because we want to widen our dataframe. will use inner join because we want to be consistent in comparing the same date ranges
daily_returns_combined = pd.concat([df_whale,df_algo,df_sp500_daily_returns],axis="columns",join="inner")
daily_returns_combined.sort_index(inplace=True)
daily_returns_combined.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios

#calculation
daily_returns_combined.pct_change()

#plot
daily_returns_combined.plot(figsize=(25,15), title="Daily Portfolio Returns and S&P 500")

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1+ daily_returns_combined).cumprod()
cumulative_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   1.160965            0.786811
# 2019-04-17                   1.157602            0.781723
# 2019-04-18                   1.159278            0.782678
# 2019-04-22                   1.156280            0.776939
# 2019-04-23                   1.164568            0.779646
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                     0.862080                1.526861  1.944990
# 2019-04-17                     0.858279                1.531781  1.924954
# 2019-04-18                     0.858778                1.534716  1.923823
# 2019-04-22                     0.855652                1.533046  1.925124
# 2019-04-23                     0.861189                1.553401  1.934691
#
#               Algo 2   S&P 500
# Date
# 2019-04-16  1.267768  1.372945
# 2019-04-17  1.261140  1.369823
# 2019-04-18  1.259590  1.371986
# ...

# %%
# Plot cumulative returns
cumulative_returns.plot(figsize=(25,15), title="Cumulative Portfolio and S&P 500 Returns")

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
#found grid=True in Pandas documentation
cumulative_returns.plot(kind="box", figsize=(25,10), grid=True, title="Visualization of Portfolio Risk")

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_port_std = daily_returns_combined.std()
all_port_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
#included in above
# Determine which portfolios are riskier than the S&P 500
all_port_std.sort_values()
# Out:
# PAULSON & CO.INC.              0.007023
# Algo 1                         0.007620
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 2                         0.008342
# S&P 500                        0.008554
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %% [markdown]
# ##By soring least to greatest, we can see that Tiger Global Management, and Berkshire Hathaway Inc have greater risk/volatility than the S&P 500 Index##

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = all_port_std * np.sqrt(252)
annualized_std.sort_values(ascending=False)
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

# Plot the rolling standard deviation
daily_returns_combined.rolling(window=21).std().plot(figsize=(25,15),title="Rolling 21 Day Standard Deviation")

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
all_port_corr = daily_returns_combined.corr()
all_port_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Display the correlation matrix
sns.heatmap(all_port_corr, vmin=-1, vmax=1, cmap="coolwarm")

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = daily_returns_combined['Algo 1'].cov(daily_returns_combined['S&P 500'])
covariance
# Calculate variance of S&P 500
variance = daily_returns_combined['S&P 500'].var()
variance
# Computing beta
algo1_beta = covariance / variance
algo1_beta
# Plot beta trend
rolling_covariance = daily_returns_combined['Algo 1'].rolling(window=21).cov(daily_returns_combined['S&P 500'])
rolling_variance = daily_returns_combined['S&P 500'].rolling(window=21).var()
rolling_algo1_beta = rolling_covariance / rolling_variance
rolling_algo1_beta
rolling_algo1_beta.plot(figsize=(20,10),title="Rolling 21 Day Beta of Algorithmic Portfolio #1")

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm_df = daily_returns_combined.ewm(halflife=21).mean()
ewm_df.plot(figsize=(25,15))

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (daily_returns_combined.mean() * 252) / (daily_returns_combined.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar',title="Sharpe Ratios for Each Portfolio")

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!
# ***The Algorithmic Portfolio 1 did outperform both the whale portfolios and S&P 500 Index. It had a higher cumulative return, as well as a higher Sharpe ratio, meaning the level of return compared to volatility, was more desirable. Algorithmic Portfolio 2 did not outperform the S&P 500, nor the Berkshire Hathaway portfolios.***

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock

csv_path = Path('mck_history.csv')
df_mckesson = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
df_mckesson.sort_index(inplace=True)
df_mckesson.head()
# Out:
#              Close
# Date
# 2015-03-02  228.22
# 2015-03-03  227.69
# 2015-03-04  227.67
# 2015-03-05  229.20
# 2015-03-06  224.60

# %%
# Reading data from 2nd stock
csv_path = Path('amzn_history.csv')
df_amazon = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
df_amazon.sort_index(inplace=True)
df_amazon.head()
# Out:
#              Close
# Date
# 2015-03-02  385.66
# 2015-03-03  384.61
# 2015-03-04  382.72
# 2015-03-05  387.83
# 2015-03-06  380.09

# %%
# Reading data from 3rd stock
csv_path = Path('mcd_history.csv')
df_mcdonalds = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
df_mcdonalds.sort_index(inplace=True)
df_mcdonalds.head()
# Out:
#              Close
# Date
# 2015-03-02  100.00
# 2015-03-03   99.74
# 2015-03-04  100.25
# 2015-03-05   99.11
# 2015-03-06   97.13

# %%
# Combine all stocks in a single DataFrame
alex_port = pd.concat([df_mckesson,df_amazon,df_mcdonalds],axis="columns",join="inner")
alex_port.sort_index(inplace=True)
alex_port.head()
# Out:
#              Close   Close   Close
# Date
# 2015-03-02  228.22  385.66  100.00
# 2015-03-03  227.69  384.61   99.74
# 2015-03-04  227.67  382.72  100.25
# 2015-03-05  229.20  387.83   99.11
# 2015-03-06  224.60  380.09   97.13

# %%
#check data types to confirm float
alex_port.dtypes

# Reset Date index
# Out:
# Close    float64
# Close    float64
# Close    float64
# dtype: object

# %%
# Reorganize portfolio data by having a column per symbol
columns_labels = ["MCK", "AMZN", "MCD"]
alex_port.columns = columns_labels
alex_port.head()
# Out:
#                MCK    AMZN     MCD
# Date
# 2015-03-02  228.22  385.66  100.00
# 2015-03-03  227.69  384.61   99.74
# 2015-03-04  227.67  382.72  100.25
# 2015-03-05  229.20  387.83   99.11
# 2015-03-06  224.60  380.09   97.13

# %%
# Calculate daily returns
alex_port_daily = alex_port.pct_change()
alex_port_daily

# Drop NAs
alex_port_daily = alex_port_daily.dropna()

# Display sample data
alex_port_daily.head()
# Out:
#                  MCK      AMZN       MCD
# Date
# 2015-03-03 -0.002322 -0.002723 -0.002600
# 2015-03-04 -0.000088 -0.004914  0.005113
# 2015-03-05  0.006720  0.013352 -0.011372
# 2015-03-06 -0.020070 -0.019957 -0.019978
# 2015-03-09  0.003339 -0.004025  0.005971

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
alex_port_even_weight = alex_port_daily.dot(weights)

# Display sample data
alex_port_even_weight.head()
# Out:
# Date
# 2015-03-03   -0.002548
# 2015-03-04    0.000037
# 2015-03-05    0.002900
# 2015-03-06   -0.020002
# 2015-03-09    0.001762
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
second_combine = pd.concat([daily_returns_combined, alex_port_even_weight], axis='columns', join='inner')
second_combine.sort_index(inplace=True)
second_combine.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500         0
# Date
# 2015-03-03 -0.000949 -0.004539 -0.002548
# 2015-03-04  0.002416 -0.004389  0.000037
# ...

# %%
#fix the column header for Alex custom portfolio
second_combine = second_combine.rename(columns={0: "Alex Portfolio",})
second_combine.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500  Alex Portfolio
# Date
# 2015-03-03 -0.000949 -0.004539       -0.002548
# 2015-03-04  0.002416 -0.004389        0.000037
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
second_combine.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# 0                              0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculating the standard deviation
all_ports_plus_alex_std = second_combine.std()
all_ports_plus_alex_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# Alex Portfolio                 0.011115
# dtype: float64

# %%
# Calculate the annualized `std`
all_ports_plus_alex_std_annual = all_ports_plus_alex_std * np.sqrt(252)
all_ports_plus_alex_std_annual.sort_values(ascending=False)
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# Alex Portfolio                 0.176444
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation
second_combine.rolling(window=21).std().plot(figsize=(25,15),title="Rolling 21 Day Standard Deviation")

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
all_port_plus_alex_corr = second_combine.corr()
all_port_plus_alex_corr
# Plot the Correlation
sns.heatmap(all_port_plus_alex_corr, vmin=-1, vmax=1, cmap="coolwarm")

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# Calculate covariance of a single portfolio
covariance = second_combine['Alex Portfolio'].cov(second_combine['S&P 500'])
covariance
# Out:
# 6.983777651389468e-05

# %%
# Calculate variance of S&P 500
variance = second_combine['S&P 500'].var()
variance
# Out:
# 7.316632424648712e-05

# %%
# Computing beta
alex_port_beta = covariance / variance
alex_port_beta
# Out:
# 0.9545071073766255

# %%
# Plot beta trend
rolling_covariance = second_combine['Alex Portfolio'].rolling(window=60).cov(second_combine['S&P 500'])
rolling_variance = second_combine['S&P 500'].rolling(window=60).var()
rolling_alex_beta = rolling_covariance / rolling_variance
rolling_alex_beta
rolling_alex_beta.plot(figsize=(20,10),title="Rolling 60 Day Beta of Alex Portfolio")

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
# Annualized Sharpe Ratios
sharpe_ratios_2 = (second_combine.mean() * 252) / (second_combine.std() * np.sqrt(252))
sharpe_ratios_2
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# Alex Portfolio                 0.915562
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_2.plot(kind='bar',title="Sharpe Ratios for Each Portfolio")

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
# ***My portfolio consisted of one healthcare stock (McKesson), one E-Commerce stock (Amazon), and one fast food stock (McDonalds). My portfolio had one of the highest annualized standard deviations (2nd only to Berkshire Hathaway). It did have a higher return for the level of risk assumed (Sharpe Ratio) compared to the S&P. However, it did not outperform Algorithmic 1 portfolio.***
